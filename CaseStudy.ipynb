# %%
# innstall java
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null

# install spark (change the version number if needed)
# !wget -q https://archive.apache.org/dist/spark/spark-3.0.0/spark-3.0.0-bin-hadoop3.2.tgz

# unzip the spark file to the current folder
# !tar xf spark-3.0.0-bin-hadoop3.2.tgz

# set your spark folder to your system path environment. 
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.0.0-bin-hadoop3.2"


# install findspark using pip
# !pip install -q findspark
# Out:
# ^C

# %%
# !pip install pyspark
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pyspark in /usr/local/lib/python3.8/dist-packages (3.3.1)
# Requirement already satisfied: py4j==0.10.9.5 in /usr/local/lib/python3.8/dist-packages (from pyspark) (0.10.9.5)

# %%
import findspark
findspark.init()

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder\
        .master("local")\
        .appName("CarCrashAnalysis")\
        .config('spark.ui.port', '4050')\
        .getOrCreate()

# %%
from zipfile import ZipFile

# loading the temp.zip and creating a zip object
with ZipFile("Data.zip", 'r') as zObject:

	# Extracting all the members of the zip
	# into a specific location.
	zObject.extractall(path="/Unzipped/")

# %%
df_charges_use = spark.read.option("header",True).csv("/Unzipped/Data/Charges_use.csv")
df_damages_use = spark.read.option("header",True).csv("/Unzipped/Data/Damages_use.csv")
df_endorse_use = spark.read.option("header",True).csv("/Unzipped/Data/Endorse_use.csv")
df_primary_person_use = spark.read.option("header",True).csv("/Unzipped/Data/Primary_Person_use.csv")
df_restrict_use = spark.read.option("header",True).csv("/Unzipped/Data/Restrict_use.csv")
df_units_use = spark.read.option("header",True).csv("/Unzipped/Data/Units_use.csv")

# %%
def deduplicate_df(dup_df):
  """
  De-duplicates a given dataframe
  :param dup_df: The DataFrame to be de-duplicated
  :return: De-duplicated dataframe
  """
  df = dup_df.dropDuplicates()
  return df

# %%
def load_csv_data_to_df(spark, file_path):
    """
    Read CSV data
    :param spark: spark instance
    :param file_path: path to the csv file
    :return: dataframe
    """
    return spark.read.option("inferSchema", "true").csv(file_path, header=True)

# %%
def extract_zipped_content(zipped_file_path, unzipped_files_path):
  """
  Extracts all the files present within a zipped folder to another location
  :param zipped_file_path: Location to the Zipped file
  :param unzipped_files_path: Location to the Extracted files
  """
  # loading the temp.zip and creating a zip object
  with ZipFile(f"{zipped_file_path}", 'r') as zobject:

	# Extracting all the members of the zip
	# into a specific location.
	    zobject.extractall(path=f"{unzipped_files_path}")
  print("Unzipping files successfully to : ",unzipped_files_path)

# %%
extract_zipped_content("/content/Data.zip","/content/Unzipped/")
# Out:
# Unzipping files successfully to :  /content/Unzipped/

# %%
df_charges_use = df_charges_use.dropDuplicates()
df_damages_use = df_damages_use.dropDuplicates()
df_endorse_use = df_endorse_use.dropDuplicates()
df_primary_person_use = df_primary_person_use.dropDuplicates()
df_restrict_use = df_restrict_use.dropDuplicates()
df_units_use = df_units_use.dropDuplicates()

# %%
#if df.count() > df.dropDuplicates([listOfColumns]).count():
 #   raise ValueError('Data has duplicates')

# %%
df_charges_use \
    .groupby(df_charges_use.columns) \
    .count() \
    .where('count > 1') \
    .sort('count', ascending=False) \
    .show()
# Out:
# +--------+--------+--------+------+------------+-----+
# |CRASH_ID|UNIT_NBR|PRSN_NBR|CHARGE|CITATION_NBR|count|
# +--------+--------+--------+------+------------+-----+
# +--------+--------+--------+------+------------+-----+

# %%
df_charges_use.printSchema()
# Out:
# root
#  |-- CRASH_ID: string (nullable = true)
#  |-- UNIT_NBR: string (nullable = true)
#  |-- PRSN_NBR: string (nullable = true)
#  |-- CHARGE: string (nullable = true)
#  |-- CITATION_NBR: string (nullable = true)

# %%
df_charges_use.show(5,truncate=True)
# Out:
# +--------+--------+--------+--------------------+------------+
# |CRASH_ID|UNIT_NBR|PRSN_NBR|              CHARGE|CITATION_NBR|
# +--------+--------+--------+--------------------+------------+
# |14839048|       1|       1|EVADING IN  A VEH...| 2016-000008|
# |14842539|       1|       1|FAILURE TO CONTRO...|   138474673|
# |14845037|       1|       1|DRIVERS LICENSE R...|    M105252B|
# |14845764|       1|       1|FAIL TO DRIVE IN ...|   008388006|
# |14845973|       1|       1|NO DRIVER'S LICEN...|TX4IEN0FTMG3|
# +--------+--------+--------+--------------------+------------+
# only showing top 5 rows

# %%
df_charges_use.count()
# Out:
# 115909

# %%
df_charges_use = df_charges_use.dropDuplicates()

# %%
df_charges_use.count()
# Out:
# 115909

# %%
df_damages_use.show(5,truncate=True)
# Out:
# +--------+--------------------+
# |CRASH_ID|    DAMAGED_PROPERTY|
# +--------+--------------------+
# |14852553|       CABLE BARRIER|
# |14853703|         LANDSCAPING|
# |14862814|75 FT. OF GUARD RAIL|
# |14867689|         CABLE LINES|
# |14873013|          LIGHT POLE|
# +--------+--------------------+
# only showing top 5 rows

# %%
df_endorse_use.show(5,truncate=True)
# Out:
# +--------+--------+------------------+
# |CRASH_ID|UNIT_NBR|DRVR_LIC_ENDORS_ID|
# +--------+--------+------------------+
# |14842529|       2|              NONE|
# |14843083|       1|        UNLICENSED|
# |14844479|       1|        UNLICENSED|
# |14845535|       1|              NONE|
# |14846619|       2|              NONE|
# +--------+--------+------------------+
# only showing top 5 rows

# %%
df_primary_person_use.show(5,truncate=True) #DRVR_LIC_STATE_ID
# Out:
# +--------+--------+--------+------------+------------------+--------------------+--------+-----------------+------------+------------+-------------------+---------------+--------------+-----------+---------------------+----------------+------------------+---------------------+----------------+-----------------+---------------+---------------+------------------+--------------+-------------+--------------+-------------+---------+--------------------+-----------------+---------------+--------+
# |CRASH_ID|UNIT_NBR|PRSN_NBR|PRSN_TYPE_ID|PRSN_OCCPNT_POS_ID|   PRSN_INJRY_SEV_ID|PRSN_AGE|PRSN_ETHNICITY_ID|PRSN_GNDR_ID|PRSN_EJCT_ID|       PRSN_REST_ID| PRSN_AIRBAG_ID|PRSN_HELMET_ID|PRSN_SOL_FL|PRSN_ALC_SPEC_TYPE_ID|PRSN_ALC_RSLT_ID|PRSN_BAC_TEST_RSLT|PRSN_DRG_SPEC_TYPE_ID|PRSN_DRG_RSLT_ID|DRVR_DRG_CAT_1_ID|PRSN_DEATH_TIME|INCAP_INJRY_CNT|NONINCAP_INJRY_CNT|POSS_INJRY_CNT|NON_INJRY_CNT|UNKN_INJRY_CNT|TOT_INJRY_CNT|DEATH_CNT|    DRVR_LIC_TYPE_ID|DRVR_LIC_STATE_ID|DRVR_LIC_CLS_ID|DRVR_ZIP|
# +--------+--------+--------+------------+------------------+--------------------+--------+-----------------+------------+------------+-------------------+---------------+--------------+-----------+---------------------+----------------+------------------+---------------------+----------------+-----------------+---------------+---------------+------------------+--------------+-------------+--------------+-------------+---------+--------------------+-----------------+---------------+--------+
# |14843420|       2|       1|      DRIVER|        FRONT LEFT|         NOT INJURED|      32|            WHITE|      FEMALE|          NO|SHOULDER & LAP BELT|   NOT DEPLOYED|NOT APPLICABLE|          N|                 NONE|              NA|                NA|                 NONE|  NOT APPLICABLE|   NOT APPLICABLE|           null|              0|                 0|             0|            1|             0|            0|        0|COMMERCIAL DRIVER...|            Texas|        CLASS B|   75071|
# |14845104|       1|       1|      DRIVER|        FRONT LEFT|INCAPACITATING IN...|      19|            OTHER|        MALE|          NO|SHOULDER & LAP BELT|DEPLOYED, FRONT|NOT APPLICABLE|          N|                 NONE|              NA|                NA|                 NONE|  NOT APPLICABLE|   NOT APPLICABLE|           null|              1|                 0|             0|            0|             0|            1|        0|      DRIVER LICENSE|            Texas|        CLASS C|   78065|
# |14845673|       2|       1|      DRIVER|        FRONT LEFT|         NOT INJURED|      18|            WHITE|      FEMALE|          NO|SHOULDER & LAP BELT|   NOT DEPLOYED|NOT APPLICABLE|          N|                 NONE|              NA|                NA|                 NONE|  NOT APPLICABLE|   NOT APPLICABLE|           null|              0|                 0|             0|            1|             0|            0|        0|      DRIVER LICENSE|            Texas|        CLASS C|   78148|
# |14851529|       2|       1|      DRIVER|        FRONT LEFT|         NOT INJURED|      44|         HISPANIC|      FEMALE|          NO|SHOULDER & LAP BELT|   NOT DEPLOYED|NOT APPLICABLE|          N|                 NONE|              NA|                NA|                 NONE|  NOT APPLICABLE|   NOT APPLICABLE|           null|              0|                 0|             0|            1|             0|            0|        0|      DRIVER LICENSE|            Texas|        CLASS C|   77044|
# |14854122|       1|       1|      DRIVER|        FRONT LEFT|         NOT INJURED|      20|            BLACK|      FEMALE|          NO|SHOULDER & LAP BELT|DEPLOYED, FRONT|NOT APPLICABLE|          N|                 NONE|              NA|                NA|                 NONE|  NOT APPLICABLE|   NOT APPLICABLE|           null|              0|                 0|             0|            1|             0|            0|        0|             ID CARD|            Texas|     UNLICENSED|   76006|
# +--------+--------+--------+------------+------------------+--------------------+--------+-----------------+------------+------------+-------------------+---------------+--------------+-----------+---------------------+----------------+------------------+---------------------+----------------+-----------------+---------------+---------------+------------------+--------------+-------------+--------------+-------------+---------+--------------------+-----------------+---------------+--------+
# only showing top 5 rows

# %%
df_restrict_use.show(5,truncate=True)
# Out:
# +--------+--------+--------------------+
# |CRASH_ID|UNIT_NBR| DRVR_LIC_RESTRIC_ID|
# +--------+--------+--------------------+
# |14839097|       3|WITH CORRECTIVE L...|
# |14840787|       1|TRC 545.424 APPLI...|
# |14842529|       2|                NONE|
# |14843083|       1|          UNLICENSED|
# |14844479|       1|          UNLICENSED|
# +--------+--------+--------------------+
# only showing top 5 rows

# %%
df_units_use.show(5,truncate=True) #VEH_LIC_STATE_ID #
# Out:
# +--------+--------+-------------+-------------+----------+----------------+-----------------+------------+------------+-----------+----------+--------------------+---------------+--------+-----------------+--------------------+--------------------+-----------------+--------------+--------------------+-----------------+--------------+------------------+-----------------+--------------------+--------------------+--------------------+-------------------+---------------+---------------------+---------------+------------------+--------------+-------------+--------------+-------------+---------+
# |CRASH_ID|UNIT_NBR| UNIT_DESC_ID|VEH_PARKED_FL|VEH_HNR_FL|VEH_LIC_STATE_ID|              VIN|VEH_MOD_YEAR|VEH_COLOR_ID|VEH_MAKE_ID|VEH_MOD_ID|    VEH_BODY_STYL_ID|EMER_RESPNDR_FL|OWNR_ZIP|FIN_RESP_PROOF_ID|    FIN_RESP_TYPE_ID|  VEH_DMAG_AREA_1_ID|VEH_DMAG_SCL_1_ID|FORCE_DIR_1_ID|  VEH_DMAG_AREA_2_ID|VEH_DMAG_SCL_2_ID|FORCE_DIR_2_ID|VEH_INVENTORIED_FL|  VEH_TRANSP_NAME|     VEH_TRANSP_DEST|  CONTRIB_FACTR_1_ID|  CONTRIB_FACTR_2_ID|CONTRIB_FACTR_P1_ID|VEH_TRVL_DIR_ID|FIRST_HARM_EVT_INV_ID|INCAP_INJRY_CNT|NONINCAP_INJRY_CNT|POSS_INJRY_CNT|NON_INJRY_CNT|UNKN_INJRY_CNT|TOT_INJRY_CNT|DEATH_CNT|
# +--------+--------+-------------+-------------+----------+----------------+-----------------+------------+------------+-----------+----------+--------------------+---------------+--------+-----------------+--------------------+--------------------+-----------------+--------------+--------------------+-----------------+--------------+------------------+-----------------+--------------------+--------------------+--------------------+-------------------+---------------+---------------------+---------------+------------------+--------------+-------------+--------------+-------------+---------+
# |14840049|       1|MOTOR VEHICLE|            N|         N|              TX|WVWPD63B33P045318|        2003|         BLU| VOLKSWAGEN|    PASSAT|PASSENGER CAR, 4-...|              N|   75217|                2|                  NA|RIGHT FRONT QUART...|        DAMAGED 2|             2|RIGHT BACK QUARTE...|        DAMAGED 2|             4|                 Y| CONTRACT WRECKER|1955 VILBIG, DALL...|DISREGARD STOP AN...|UNDER INFLUENCE -...|  HAD BEEN DRINKING|          NORTH|                    Y|              1|                 0|             0|            0|             0|            1|        0|
# |14840432|       2|MOTOR VEHICLE|            Y|         N|              TX|2HGES26862H501631|        2002|         MAR|      HONDA|     CIVIC|PASSENGER CAR, 4-...|              N|   77089|                1|LIABILITY INSURAN...|LEFT FRONT QUARTE...|        DAMAGED 3|             9|                  NA|               NA|            NA|                 N|CHALLENGER TOWING|   8000 GALVESTON RD|                NONE|                  NA|                 NA|          NORTH|                    Y|              0|                 0|             0|            0|             0|            0|        0|
# |14845208|       2|MOTOR VEHICLE|            N|         N|              AZ|1GDGG31C481910742|          NA|         ONG|        GMC|   UNKNOWN|               TRUCK|              N|   85036|                1|PROOF OF LIABILIT...|LEFT FRONT QUARTE...|        DAMAGED 2|             9|                  NA|               NA|            NA|                 N|           DRIVER|         DRIVEN AWAY|                NONE|                  NA|                 NA|          SOUTH|                    Y|              0|                 0|             0|            3|             0|            0|        0|
# |14847652|       1|MOTOR VEHICLE|            N|         N|              TX|1GCEK19B96Z176950|        2006|         BGE|  CHEVROLET| SILVERADO|              PICKUP|              N|   76088|                1|PROOF OF LIABILIT...|LEFT SIDE DAMAGE ...|DAMAGED 1 MINIMUM|             9|                  NA|               NA|            NA|                 N|             null|                null|  TURNED WHEN UNSAFE|                  NA|                 NA|          NORTH|                    Y|              0|                 0|             0|            1|             0|            0|        0|
# |14848872|       2|MOTOR VEHICLE|            N|         N|              TX|1FDWW36S63EB30029|        2003|         WHI|       FORD|      F350|              PICKUP|              N|   78744|                4|                  NA|FRONT END (LEFT) ...|        DAMAGED 2|            12|                  NA|               NA|            NA|                 N|        NOT TOWED|           NOT TOWED|                NONE|                  NA|                 NA|          SOUTH|                    Y|              0|                 0|             0|            2|             0|            0|        0|
# +--------+--------+-------------+-------------+----------+----------------+-----------------+------------+------------+-----------+----------+--------------------+---------------+--------+-----------------+--------------------+--------------------+-----------------+--------------+--------------------+-----------------+--------------+------------------+-----------------+--------------------+--------------------+--------------------+-------------------+---------------+---------------------+---------------+------------------+--------------+-------------+--------------+-------------+---------+
# only showing top 5 rows

# %% [markdown]
# ## Analytics 1

# %%
#Analytics 1: Find the number of crashes (accidents) in which number of persons killed are male?
df_primary_person_use.select('PRSN_GNDR_ID').distinct().show()
# Out:
# +------------+
# |PRSN_GNDR_ID|
# +------------+
# |          NA|
# |     UNKNOWN|
# |        MALE|
# |      FEMALE|
# +------------+

# %%
df_primary_person_use.select('PRSN_NBR').distinct().show()
# Out:
# +--------+
# |PRSN_NBR|
# +--------+
# |       1|
# +--------+

# %%
male_accidents_df = df_primary_person_use.filter((df_primary_person_use.PRSN_GNDR_ID == "MALE") & (df_primary_person_use.DEATH_CNT == 1))

# %%
male_accidents_df.show(5,truncate=True)
# Out:
# +--------+--------+--------+------------+--------------------+-----------------+--------+-----------------+------------+--------------+-------------------+--------------+--------------+-----------+---------------------+----------------+------------------+---------------------+----------------+-----------------+---------------+---------------+------------------+--------------+-------------+--------------+-------------+---------+--------------------+-----------------+---------------+--------+
# |CRASH_ID|UNIT_NBR|PRSN_NBR|PRSN_TYPE_ID|  PRSN_OCCPNT_POS_ID|PRSN_INJRY_SEV_ID|PRSN_AGE|PRSN_ETHNICITY_ID|PRSN_GNDR_ID|  PRSN_EJCT_ID|       PRSN_REST_ID|PRSN_AIRBAG_ID|PRSN_HELMET_ID|PRSN_SOL_FL|PRSN_ALC_SPEC_TYPE_ID|PRSN_ALC_RSLT_ID|PRSN_BAC_TEST_RSLT|PRSN_DRG_SPEC_TYPE_ID|PRSN_DRG_RSLT_ID|DRVR_DRG_CAT_1_ID|PRSN_DEATH_TIME|INCAP_INJRY_CNT|NONINCAP_INJRY_CNT|POSS_INJRY_CNT|NON_INJRY_CNT|UNKN_INJRY_CNT|TOT_INJRY_CNT|DEATH_CNT|    DRVR_LIC_TYPE_ID|DRVR_LIC_STATE_ID|DRVR_LIC_CLS_ID|DRVR_ZIP|
# +--------+--------+--------+------------+--------------------+-----------------+--------+-----------------+------------+--------------+-------------------+--------------+--------------+-----------+---------------------+----------------+------------------+---------------------+----------------+-----------------+---------------+---------------+------------------+--------------+-------------+--------------+-------------+---------+--------------------+-----------------+---------------+--------+
# |14960717|       4|       1|      DRIVER|          FRONT LEFT|           KILLED|      74|            WHITE|        MALE|            NO|SHOULDER & LAP BELT|NOT APPLICABLE|NOT APPLICABLE|          N|                 NONE|              NA|                NA|                 NONE|  NOT APPLICABLE|   NOT APPLICABLE|       14:17:00|              0|                 0|             0|            0|             0|            0|        1|      DRIVER LICENSE|            Texas|        CLASS C|   77474|
# |15200175|       2|       1|  PEDESTRIAN|PEDESTRIAN, PEDAL...|           KILLED|      43|            BLACK|        MALE|NOT APPLICABLE|     NOT APPLICABLE|NOT APPLICABLE|NOT APPLICABLE|          N|                BLOOD|        Positive|              0.19|                BLOOD|        Negative|   NOT APPLICABLE|       02:37:00|              0|                 0|             0|            0|             0|            0|        1|                  NA|               NA|             NA|    null|
# |15246994|       1|       1|      DRIVER|          FRONT LEFT|           KILLED|      56|            WHITE|        MALE|           YES|SHOULDER & LAP BELT|  NOT DEPLOYED|NOT APPLICABLE|          N|                BLOOD|        Negative|                 0|                BLOOD|        Negative|   NOT APPLICABLE|       17:25:00|              0|                 0|             0|            0|             0|            0|        1|COMMERCIAL DRIVER...|            Texas|        CLASS B|   78223|
# |15267097|       2|       1|      DRIVER|          FRONT LEFT|           KILLED|      30|            WHITE|        MALE|            NO|SHOULDER & LAP BELT|  NOT DEPLOYED|NOT APPLICABLE|          N|                BLOOD|        Negative|                 0|                BLOOD|        Positive|         CANNABIS|       16:20:00|              0|                 0|             0|            0|             0|            0|        1|             ID CARD|            Texas|     UNLICENSED|   77541|
# |15231100|       2|       1|  PEDESTRIAN|PEDESTRIAN, PEDAL...|           KILLED|      60|         HISPANIC|        MALE|NOT APPLICABLE|     NOT APPLICABLE|NOT APPLICABLE|NOT APPLICABLE|          N|                BLOOD|        Positive|              0.25|                BLOOD|        Positive|  CNS DEPRESSANTS|       21:13:00|              0|                 0|             0|            0|             0|            0|        1|      DRIVER LICENSE|            Texas|        CLASS A|   79902|
# +--------+--------+--------+------------+--------------------+-----------------+--------+-----------------+------------+--------------+-------------------+--------------+--------------+-----------+---------------------+----------------+------------------+---------------------+----------------+-----------------+---------------+---------------+------------------+--------------+-------------+--------------+-------------+---------+--------------------+-----------------+---------------+--------+
# only showing top 5 rows

# %%
male_accidents_df.count()
# Out:
# 182

# %%
print("Number of Males who died in Car Crash are",male_accidents_df.count())
# Out:
# Number of Males who died in Car Crash are 182

# %% [markdown]
# ## Analytics 2

# %%
#Analytics 2: How many two wheelers are booked for crashes
df_units_use.select('VEH_BODY_STYL_ID').distinct().show()
# Out:
# +--------------------+
# |    VEH_BODY_STYL_ID|
# +--------------------+
# |                 BUS|
# |                  NA|
# |                 VAN|
# |              PICKUP|
# |SPORT UTILITY VEH...|
# |PASSENGER CAR, 4-...|
# |          FIRE TRUCK|
# |               TRUCK|
# |             UNKNOWN|
# |           AMBULANCE|
# |    POLICE CAR/TRUCK|
# |          MOTORCYCLE|
# |   YELLOW SCHOOL BUS|
# |   POLICE MOTORCYCLE|
# |PASSENGER CAR, 2-...|
# |       TRUCK TRACTOR|
# |      FARM EQUIPMENT|
# |NEV-NEIGHBORHOOD ...|
# |OTHER  (EXPLAIN I...|
# |        NOT REPORTED|
# +--------------------+

# %%
two_wheelers_df = df_units_use.filter(df_units_use.VEH_BODY_STYL_ID.contains("MOTORCYCLE"))

# %%
two_wheelers_df = two_wheelers_df.dropDuplicates()

# %%
print("Count of 2-Wheelers Booked for Crash:",two_wheelers_df.count() )
# Out:
# Count of 2-Wheelers Booked for Crash: 773

# %% [markdown]
# ## Analytics 3

# %%
# Which state has highest number of accidents in which females are involved?

# %%
from pyspark.sql import functions as F
female_state_accidents_df = df_primary_person_use.filter(df_primary_person_use.PRSN_GNDR_ID == "FEMALE"). \
            groupby("DRVR_LIC_STATE_ID").count(). \
            orderBy(F.col("count").desc())

# %%
female_state_accidents_df.show(1)
female_state_accidents = female_state_accidents_df.select("DRVR_LIC_STATE_ID")
# Out:
# +-----------------+-----+
# |DRVR_LIC_STATE_ID|count|
# +-----------------+-----+
# |            Texas|53319|
# +-----------------+-----+
# only showing top 1 row

# %%
print("State with highest number of accidents in which Females are involved is:", female_state_accidents.collect()[0][0])
#female_state_accidents.first().DRVR_LIC_STATE_ID
# Out:
# State with highest number of accidents in which Females are involved is: Texas

# %% [markdown]
# ## Analytics 4

# %%
# Which are the Top 5th to 15th VEH_MAKE_IDs that contribute to a largest number of injuries including death

# %%
df_units_use.select("VEH_MAKE_ID").distinct().show(df_units_use.count(),False)
# Out:
# +---------------------------------+
# |VEH_MAKE_ID                      |
# +---------------------------------+
# |UNITED EXPRESS LINE INC          |
# |UTILIMASTER                      |
# |AMERICAN IRON HORSE              |
# |ACURA                            |
# |NOVA                             |
# |FRUEHAUF                         |
# |WHITE                            |
# |MOTOR COACH MND INC              |
# |MCLAREN                          |
# |PIERCE                           |
# |PORSCHE                          |
# |WHITEGMC                         |
# |FREIGHTLINER                     |
# |BUELL                            |
# |STERLING                         |
# |HYUNDAI                          |
# |INTERNATIONAL                    |
# |PETER PIRSCH & SONS              |
# |FIAT                             |
# |GILLIG                           |
# |NA                               |
# |MIDLAND MANUFACTURING LIMITED    |
# |DATSUN                           |
# |CAN-AM                           |
# |HYUNDAI STEEL INDUSTRIES         |
# |COUNTRY COACH                    |
# |NISSAN DIESEL                    |
# |TOYOTA                           |
# |RAM                              |
# |SUBARU                           |
# |NISSAN                           |
# |IC CORPORATION                   |
# |CHALLENGE-COOK BROTHERS INC      |
# |POLARIS                          |
# |FLOE INTERNATIONAL               |
# |BENTLEY                          |
# |EMERGENCY ONE                    |
# |INFINITI                         |
# |SUZUKI                           |
# |HINO                             |
# |FORD                             |
# |AUDI                             |
# |PREVOST                          |
# |FLOW BOY MFG                     |
# |FERRARI                          |
# |ISUZU                            |
# |OLDSMOBILE                       |
# |WESTERN TRUCK & TRAILER CO       |
# |MINI                             |
# |SAAB                             |
# |KYMCO                            |
# |ALFA ROMEO                       |
# |INTERNATIONAL TANK & TRAILER CORP|
# |HEIL CO                          |
# |MANAC INC                        |
# |BRI-MAR MANUFACTURING LLC        |
# |EAGER BEAVER                     |
# |DODGE                            |
# |CHEVROLET                        |
# |JAGUAR                           |
# |HOGG/DAVIS INC                   |
# |BUGATTI                          |
# |WINNEBAGO                        |
# |SPARTA MANUFACTURING CORP        |
# |MCI (LES AUTO BUS)               |
# |MERCURY                          |
# |D & B TRAILER                    |
# |SUPREME CORP                     |
# |LEXUS                            |
# |NORTH AMERICAN BUS               |
# |JEEP                             |
# |VOLVO                            |
# |GRAYCO                           |
# |JOHN DEERE                       |
# |GM                               |
# |TESLA                            |
# |DUCATI                           |
# |OTTAWA                           |
# |UNKNOWN                          |
# |SPARTAN                          |
# |MAC LTT                          |
# |MAZDA                            |
# |DAEWOO                           |
# |REQUIRES INTERPRETATION          |
# |BMW                              |
# |INDEPENDENT TRAILER MFG          |
# |MASERATI                         |
# |VOLKSWAGEN                       |
# |GEO                              |
# |PONTIAC                          |
# |EAGLE                            |
# |BLUE BIRD                        |
# |WORKHORSE                        |
# |HOMEMADE VEHICLE                 |
# |AUTOCAR LLC                      |
# |GENERAL TRAILER CO               |
# |ALL OTHER MAKES                  |
# |HARLEY-DAVIDSON                  |
# |VESPA                            |
# |FORETRAVEL                       |
# |FEDERAL MOTORS                   |
# |YAMAHA                           |
# |KIA                              |
# |HUMMER                           |
# |WESTERN STAR                     |
# |MITSUBISHI FUSO                  |
# |HONDA                            |
# |OTHER (EXPLAIN IN NARRATIVE)     |
# |SATURN                           |
# |INTERMOUNTAIN WHOLE SALE INC     |
# |STEPHENS PNEUMATIC               |
# |KAWASAKI                         |
# |GMC                              |
# |VAN HOOL                         |
# |TRI-QUEST INC                    |
# |CRANE CARRIER                    |
# |EAGLE TRANSIT                    |
# |SMART                            |
# |INDIAN                           |
# |APRILIA                          |
# |CADILLAC                         |
# |ELDORADO                         |
# |NEW FLYER                        |
# |NABORS TRAILERS                  |
# |GALBREATH INC                    |
# |RENAULT                          |
# |ROLLS-ROYCE                      |
# |PLYMOUTH                         |
# |ROAD RAILER                      |
# |ULTRA LITE MFG                   |
# |PIAGGIO                          |
# |LINCOLN                          |
# |MACK                             |
# |THOMAS                           |
# |ASTON MARTIN                     |
# |FEATHERLITE MFG INC              |
# |LOTUS                            |
# |NOVA FABRICATING                 |
# |ORION                            |
# |VICTORY                          |
# |CATERPILLAR                      |
# |AM GENERAL                       |
# |U-HAUL INTERNATIONAL             |
# |KENTUCKY MFG                     |
# |MURPHY MANUFACTURING CO          |
# |MERCEDES-BENZ                    |
# |BUICK                            |
# |KENWORTH                         |
# |HYOSUNG                          |
# |BUS & COACH INTL                 |
# |AUTOCAR                          |
# |CHRYSLER                         |
# |AMERICAN MOTORS                  |
# |INTERNATIONAL TRAILER CORP       |
# |LAND ROVER                       |
# |WABASH NATIONAL CORP             |
# |MITSUBISHI                       |
# |PETERBILT                        |
# +---------------------------------+

# %%
casualties_df = df_units_use.filter(df_units_use.VEH_MAKE_ID != "NA"). \
            withColumn('TOT_CASUALTIES_CNT', df_units_use[35] + df_units_use[36]). \
            groupby("VEH_MAKE_ID").sum("TOT_CASUALTIES_CNT"). \
            withColumnRenamed("sum(TOT_CASUALTIES_CNT)", "TOT_CASUALTIES"). \
            orderBy(F.col("TOT_CASUALTIES").desc())

# %%
casualties_df.show()
# Out:
# +-------------+--------------+
# |  VEH_MAKE_ID|TOT_CASUALTIES|
# +-------------+--------------+
# |    CHEVROLET|        7000.0|
# |         FORD|        6944.0|
# |       TOYOTA|        4227.0|
# |        DODGE|        3138.0|
# |       NISSAN|        3114.0|
# |        HONDA|        2892.0|
# |          GMC|        1246.0|
# |      HYUNDAI|        1103.0|
# |          KIA|        1049.0|
# |         JEEP|         988.0|
# |     CHRYSLER|         955.0|
# |        MAZDA|         711.0|
# |   VOLKSWAGEN|         582.0|
# |      PONTIAC|         564.0|
# |        LEXUS|         523.0|
# |        BUICK|         521.0|
# |   MITSUBISHI|         510.0|
# |     CADILLAC|         498.0|
# |      MERCURY|         397.0|
# |MERCEDES-BENZ|         393.0|
# +-------------+--------------+
# only showing top 20 rows

# %%
df_top_casualties = casualties_df.limit(14).subtract(casualties_df.limit(4))

# %%
df_top_casualties.show()
# Out:
# +-----------+--------------+
# |VEH_MAKE_ID|TOT_CASUALTIES|
# +-----------+--------------+
# |     NISSAN|        3114.0|
# |      HONDA|        2892.0|
# |        GMC|        1246.0|
# |    HYUNDAI|        1103.0|
# |        KIA|        1049.0|
# |       JEEP|         988.0|
# |   CHRYSLER|         955.0|
# |      MAZDA|         711.0|
# | VOLKSWAGEN|         582.0|
# |    PONTIAC|         564.0|
# +-----------+--------------+

# %%
from pyspark.sql.window import Window
"""w = Window.orderBy(F.col("TOT_CASUALTIES").desc())
casualties_df = casualties_df.withColumn("index", F.row_number().over(w))
casualties_df.show()"""
# Out:
# 'w = Window.orderBy(F.col("TOT_CASUALTIES").desc())\ncasualties_df = casualties_df.withColumn("index", F.row_number().over(w))\ncasualties_df.show()'

# %%
list_veh = ""
for i in  df_top_casualties.select('VEH_MAKE_ID').rdd.flatMap(lambda x: x).collect():
  list_veh += i + ", "
list_veh.strip(", ")
# Out:
# 'NISSAN, HONDA, GMC, HYUNDAI, KIA, JEEP, CHRYSLER, MAZDA, VOLKSWAGEN, PONTIAC'

# %%
print("Top 5th to 15th VEH_MAKE_IDs that contribute to a largest number of injuries including death are: ", list_veh.strip(", "))
# Out:
# Top 5th to 15th VEH_MAKE_IDs that contribute to a largest number of injuries including death are:  NISSAN, HONDA, GMC, HYUNDAI, KIA, JEEP, CHRYSLER, MAZDA, VOLKSWAGEN, PONTIAC

# %% [markdown]
# ## Analytics 5

# %%
#For all the body styles involved in crashes, mention the top ethnic user group of each unique body style
joined_eth_style = df_primary_person_use.join(df_units_use,df_primary_person_use.CRASH_ID ==  df_units_use.CRASH_ID,"inner")

# %%
joined_eth_style. \
filter((~joined_eth_style.VEH_BODY_STYL_ID.isin(["NA", "UNKNOWN", "NOT REPORTED","OTHER  (EXPLAIN IN NARRATIVE)"])) & (~joined_eth_style.PRSN_ETHNICITY_ID.isin(["NA","UNKNOWN"]))). \
groupBy("VEH_BODY_STYL_ID","PRSN_ETHNICITY_ID").count(). \
withColumn("row_number", F.row_number().over(Window.partitionBy("VEH_BODY_STYL_ID"). \
                                             orderBy(F.col("VEH_BODY_STYL_ID").desc(),F.col("count").desc()))). \
                                             filter(F.col("row_number")==1). \
                                             orderBy(F.col("count").desc()). \
                                             drop("row_number", "count"). \
                                             show()
# Out:
# +--------------------+-----------------+
# |    VEH_BODY_STYL_ID|PRSN_ETHNICITY_ID|
# +--------------------+-----------------+
# |PASSENGER CAR, 4-...|            WHITE|
# |              PICKUP|            WHITE|
# |SPORT UTILITY VEH...|            WHITE|
# |PASSENGER CAR, 2-...|            WHITE|
# |                 VAN|            WHITE|
# |               TRUCK|            WHITE|
# |       TRUCK TRACTOR|            WHITE|
# |          MOTORCYCLE|            WHITE|
# |    POLICE CAR/TRUCK|            WHITE|
# |                 BUS|         HISPANIC|
# |   YELLOW SCHOOL BUS|            WHITE|
# |           AMBULANCE|            WHITE|
# |          FIRE TRUCK|            WHITE|
# |      FARM EQUIPMENT|            WHITE|
# |NEV-NEIGHBORHOOD ...|            WHITE|
# |   POLICE MOTORCYCLE|         HISPANIC|
# +--------------------+-----------------+

# %%
joined_eth_style. \
filter((~joined_eth_style.VEH_BODY_STYL_ID.isin(["NA", "UNKNOWN", "NOT REPORTED","OTHER  (EXPLAIN IN NARRATIVE)"])) & (~joined_eth_style.PRSN_ETHNICITY_ID.isin(["NA","UNKNOWN"]))). \
groupBy("VEH_BODY_STYL_ID","PRSN_ETHNICITY_ID").count(). \
withColumn("row_number", F.row_number().over(Window.partitionBy("VEH_BODY_STYL_ID"). \
                                             orderBy(F.col("VEH_BODY_STYL_ID").desc(),F.col("count").desc()))). \
                                             filter(F.col("row_number")==1). \
                                             orderBy(F.col("count").desc()). \
                                             show()
# Out:
# +--------------------+-----------------+-----+----------+
# |    VEH_BODY_STYL_ID|PRSN_ETHNICITY_ID|count|row_number|
# +--------------------+-----------------+-----+----------+
# |PASSENGER CAR, 4-...|            WHITE|58283|         1|
# |              PICKUP|            WHITE|38295|         1|
# |SPORT UTILITY VEH...|            WHITE|33884|         1|
# |PASSENGER CAR, 2-...|            WHITE| 9865|         1|
# |                 VAN|            WHITE| 5206|         1|
# |               TRUCK|            WHITE| 3347|         1|
# |       TRUCK TRACTOR|            WHITE| 2951|         1|
# |          MOTORCYCLE|            WHITE|  840|         1|
# |    POLICE CAR/TRUCK|            WHITE|  366|         1|
# |                 BUS|         HISPANIC|  208|         1|
# |   YELLOW SCHOOL BUS|            WHITE|  131|         1|
# |           AMBULANCE|            WHITE|   90|         1|
# |          FIRE TRUCK|            WHITE|   69|         1|
# |      FARM EQUIPMENT|            WHITE|   54|         1|
# |NEV-NEIGHBORHOOD ...|            WHITE|    6|         1|
# |   POLICE MOTORCYCLE|         HISPANIC|    3|         1|
# +--------------------+-----------------+-----+----------+

# %%
joined_eth_style.filter(joined_eth_style.VEH_BODY_STYL_ID == "POLICE MOTORCYCLE").groupBy("PRSN_ETHNICITY_ID").count().show()
# Out:
# +-----------------+-----+
# |PRSN_ETHNICITY_ID|count|
# +-----------------+-----+
# |            WHITE|    2|
# |            BLACK|    1|
# |         HISPANIC|    3|
# +-----------------+-----+

# %% [markdown]
# ## Analytics 6

# %%
#Among the crashed cars, what are the Top 5 Zip Codes with highest number crashes with alcohols as the 
#contributing factor to a crash (Use Driver Zip Code)

# %%
test = df_units_use.join(df_primary_person_use, on=['CRASH_ID'], how='inner'). \
            dropna(subset=["DRVR_ZIP"]). \
            filter(F.col("CONTRIB_FACTR_1_ID").contains("ALCOHOL") | F.col("CONTRIB_FACTR_2_ID").contains("ALCOHOL")). \
            groupby("DRVR_ZIP").count().orderBy(F.col("count").desc())

# %%
test = df_units_use.join(df_primary_person_use, on=['CRASH_ID'], how='inner'). \
            dropna(subset=["DRVR_ZIP"]). \
            filter(F.col("CONTRIB_FACTR_1_ID").contains("ALCOHOL") | F.col("CONTRIB_FACTR_2_ID").contains("ALCOHOL"))

# %%
test.select("CONTRIB_FACTR_1_ID").filter(F.col("CONTRIB_FACTR_1_ID").contains("ALCOHOL")).distinct().show(truncate=False)
# Out:
# +-------------------------+
# |CONTRIB_FACTR_1_ID       |
# +-------------------------+
# |UNDER INFLUENCE - ALCOHOL|
# +-------------------------+

# %%
test.select("CONTRIB_FACTR_2_ID").filter(F.col("CONTRIB_FACTR_2_ID").contains("ALCOHOL")).distinct().show(truncate=False)
# Out:
# +-------------------------+
# |CONTRIB_FACTR_2_ID       |
# +-------------------------+
# |UNDER INFLUENCE - ALCOHOL|
# +-------------------------+

# %%
df_units_use.join(df_primary_person_use, on=['CRASH_ID'], how='inner'). \
            dropna(subset=["DRVR_ZIP"]). \
            filter(F.col("CONTRIB_FACTR_1_ID").contains("ALCOHOL") | F.col("CONTRIB_FACTR_2_ID").contains("ALCOHOL")). \
            groupby("DRVR_ZIP").count().orderBy(F.col("count").desc()).show(5)
# Out:
# +--------+-----+
# |DRVR_ZIP|count|
# +--------+-----+
# |   76010|   75|
# |   78521|   61|
# |   75067|   54|
# |   78574|   47|
# |   75052|   43|
# +--------+-----+
# only showing top 5 rows

# %% [markdown]
# ## Analytics 7

# %%
#Count of Distinct Crash IDs where No Damaged Property was observed and Damage Level (VEH_DMAG_SCL~) is above 4 and car avails Insurance

# %%
insured_no_dmg_property = df_units_use.join(df_damages_use, on=['CRASH_ID'], how='inner'). \
filter((F.col("DAMAGED_PROPERTY").rlike("NO DAMAGE") | (F.col("DAMAGED_PROPERTY").rlike("NONE"))) 
& ((F.col("VEH_DMAG_SCL_1_ID").rlike("[5-9]")) | ((F.col("VEH_DMAG_SCL_2_ID").rlike("[5-9]"))))). \
filter((F.col("FIN_RESP_TYPE_ID") == "PROOF OF LIABILITY INSURANCE") | (F.col("FIN_RESP_TYPE_ID") == "INSURANCE BINDER") | (F.col("FIN_RESP_TYPE_ID") == "LIABILITY INSURANCE POLICY"))

# %%
insured_no_dmg_property = df_units_use.join(df_damages_use, on=['CRASH_ID'], how='inner'). \
filter((F.col("DAMAGED_PROPERTY").rlike("NO DAMAGE")) | (F.col("DAMAGED_PROPERTY").rlike("NONE"))). \
filter((F.col("VEH_DMAG_SCL_1_ID").rlike("[5-9]")) | (F.col("VEH_DMAG_SCL_2_ID").rlike("[5-9]"))). \
filter((F.col("FIN_RESP_TYPE_ID") == "PROOF OF LIABILITY INSURANCE") | (F.col("FIN_RESP_TYPE_ID") == "INSURANCE BINDER") | (F.col("FIN_RESP_TYPE_ID") == "LIABILITY INSURANCE POLICY"))

# %%
insured_no_dmg_property.show(truncate=False)
# Out:
# +--------+--------+-------------+-------------+----------+----------------+-----------------+------------+------------+-----------+----------+---------------------+---------------+--------+-----------------+----------------------------+---------------------------------------------+-----------------+--------------+--------------------------------------+-----------------+--------------+------------------+---------------------------------+---------------------------------------+------------------------------+------------------+----------------------------+---------------+---------------------+---------------+------------------+--------------+-------------+--------------+-------------+---------+---------------------------------------+
# |CRASH_ID|UNIT_NBR|UNIT_DESC_ID |VEH_PARKED_FL|VEH_HNR_FL|VEH_LIC_STATE_ID|VIN              |VEH_MOD_YEAR|VEH_COLOR_ID|VEH_MAKE_ID|VEH_MOD_ID|VEH_BODY_STYL_ID     |EMER_RESPNDR_FL|OWNR_ZIP|FIN_RESP_PROOF_ID|FIN_RESP_TYPE_ID            |VEH_DMAG_AREA_1_ID                           |VEH_DMAG_SCL_1_ID|FORCE_DIR_1_ID|VEH_DMAG_AREA_2_ID                    |VEH_DMAG_SCL_2_ID|FORCE_DIR_2_ID|VEH_INVENTORIED_FL|VEH_TRANSP_NAME                  |VEH_TRANSP_DEST                        |CONTRIB_FACTR_1_ID            |CONTRIB_FACTR_2_ID|CONTRIB_FACTR_P1_ID         |VEH_TRVL_DIR_ID|FIRST_HARM_EVT_INV_ID|INCAP_INJRY_CNT|NONINCAP_INJRY_CNT|POSS_INJRY_CNT|NON_INJRY_CNT|UNKN_INJRY_CNT|TOT_INJRY_CNT|DEATH_CNT|DAMAGED_PROPERTY                       |
# +--------+--------+-------------+-------------+----------+----------------+-----------------+------------+------------+-----------+----------+---------------------+---------------+--------+-----------------+----------------------------+---------------------------------------------+-----------------+--------------+--------------------------------------+-----------------+--------------+------------------+---------------------------------+---------------------------------------+------------------------------+------------------+----------------------------+---------------+---------------------+---------------+------------------+--------------+-------------+--------------+-------------+---------+---------------------------------------+
# |15307513|1       |MOTOR VEHICLE|N            |N         |TX              |1G1ZB5EB0AF315400|NA          |BRO         |CHEVROLET  |MALIBU    |PASSENGER CAR, 4-DOOR|N              |77449   |1                |PROOF OF LIABILITY INSURANCE|FRONT END DAMAGE DISTRIBUTED IMPACT          |DAMAGED 5        |NA            |NA                                    |NA               |NA            |N                 |LONE STAR AUTO SERVICE #707      |17715 CLAY RD.                         |NONE                          |NA                |NA                          |EAST           |Y                    |0              |1                 |0             |0            |0             |1            |0        |NONE                                   |
# |14885395|2       |MOTOR VEHICLE|N            |N         |TX              |1FTFN1CT7DFAS2913|NA          |BLK         |FORD       |F150      |PICKUP               |N              |77077   |1                |LIABILITY INSURANCE POLICY  |FRONT END DAMAGE DISTRIBUTED IMPACT          |DAMAGED 6        |NA            |NA                                    |NA               |NA            |Y                 |MOTORSPORTS WRECKER & RECOVERY   |20090 A FRANZ RD. KATY, TX 77449       |NONE                          |NA                |NA                          |SOUTH          |Y                    |0              |0                 |0             |1            |0             |0            |0        |NONE                                   |
# |15232090|1       |MOTOR VEHICLE|N            |N         |TX              |1FAFP3835YW215863|2000        |WHI         |FORD       |FOCUS     |PASSENGER CAR, 4-DOOR|N              |77084   |1                |PROOF OF LIABILITY INSURANCE|FRONT END DAMAGE DISTRIBUTED IMPACT          |DAMAGED 5        |NA            |NA                                    |NA               |NA            |N                 |CERTIFIED TOWING & TRANSPORT #278|5114 HWY. 6 NORTH                      |DISREGARD STOP AND GO SIGNAL  |NA                |NA                          |NORTH          |Y                    |0              |1                 |0             |0            |0             |1            |0        |NONE                                   |
# |14894076|2       |MOTOR VEHICLE|N            |N         |TX              |1FMK15578LA66436 |NA          |BLK         |FORD       |EXPEDITION|SPORT UTILITY VEHICLE|N              |77449   |1                |PROOF OF LIABILITY INSURANCE|FRONT END DAMAGE DISTRIBUTED IMPACT          |DAMAGED 5        |12            |NA                                    |NA               |NA            |N                 |GOLBOW'S WRECKER                 |21822 FRANZ RD. KATY, TX 77449         |NONE                          |NA                |NA                          |SOUTH          |Y                    |0              |0                 |0             |4            |0             |0            |0        |NONE                                   |
# |14870169|2       |MOTOR VEHICLE|N            |N         |TX              |1HGCM56396A044079|2006        |BLU         |HONDA      |ACCORD    |PASSENGER CAR, 2-DOOR|N              |77050   |1                |LIABILITY INSURANCE POLICY  |FRONT END (RIGHT)  DAMAGE PARTIAL CONTACT    |DAMAGED 7 HIGHEST|1             |NA                                    |NA               |NA            |N                 |JJ TOWING                        |5710 CAMPBELL RD HOUSTON, TX 77041     |NONE                          |NA                |NA                          |NORTH          |Y                    |0              |0                 |0             |1            |0             |0            |0        |NONE                                   |
# |14974797|1       |MOTOR VEHICLE|N            |N         |TX              |1HGCG1650YA077864|2000        |GLD         |HONDA      |ACCORD    |PASSENGER CAR, 4-DOOR|N              |77396   |1                |PROOF OF LIABILITY INSURANCE|FRONT END DAMAGE DISTRIBUTED IMPACT          |DAMAGED 5        |12            |NA                                    |NA               |NA            |N                 |CALDERON TOWING                  |11815 1/2 MISTY VALLEY HOUSTON,TX 77066|FAILED TO CONTROL SPEED       |NA                |NA                          |NORTHEAST      |Y                    |0              |0                 |1             |0            |0             |1            |0        |GUARD RAIL (POSSIBLE CONTACT-NO DAMAGE)|
# |15249931|1       |MOTOR VEHICLE|N            |N         |TX              |3VWSG69M42M006720|2002        |SIL         |VOLKSWAGEN |JETTA     |PASSENGER CAR, 4-DOOR|N              |76067   |1                |PROOF OF LIABILITY INSURANCE|FRONT END DAMAGE DISTRIBUTED IMPACT          |DAMAGED 6        |12            |NA                                    |NA               |NA            |Y                 |SARGENTS WRECKER                 |3601 N FM 51 WEATHERFORD TX 76085      |UNDER INFLUENCE - ALCOHOL     |NA                |NA                          |WEST           |Y                    |0              |0                 |0             |1            |0             |0            |0        |NONE                                   |
# |14996273|1       |MOTOR VEHICLE|N            |N         |TX              |1FTEX1CW0AFA89719|NA          |NA          |FORD       |F150      |PICKUP               |N              |78217   |1                |PROOF OF LIABILITY INSURANCE|BACK END DAMAGE DISTRIBUTED IMPACT           |DAMAGED 5        |6             |NA                                    |NA               |NA            |N                 |null                             |null                                   |OTHER (EXPLAIN IN NARRATIVE)  |NA                |OTHER (EXPLAIN IN NARRATIVE)|UNKNOWN        |Y                    |0              |0                 |0             |1            |0             |0            |0        |NONE                                   |
# |15232090|2       |MOTOR VEHICLE|N            |N         |TX              |3N1AB61E98L690537|NA          |98          |NISSAN     |SENTRA    |PASSENGER CAR, 4-DOOR|N              |77064   |1                |PROOF OF LIABILITY INSURANCE|RIGHT SIDE DAMAGE ANGULAR IMPACT             |DAMAGED 5        |NA            |BACK END (LEFT) DAMAGE PARTIAL CONTACT|DAMAGED 2        |NA            |N                 |WORLD TECH AUTO #758             |17623 F.M. 529                         |NONE                          |NA                |NA                          |EAST           |Y                    |2              |0                 |0             |0            |0             |2            |0        |NONE                                   |
# |14881426|1       |MOTOR VEHICLE|N            |N         |TX              |1G1ZT58F97F240474|2007        |GLD         |CHEVROLET  |MALIBU    |PASSENGER CAR, 4-DOOR|N              |77584   |1                |PROOF OF LIABILITY INSURANCE|FRONT END DAMAGE DISTRIBUTED IMPACT          |DAMAGED 7 HIGHEST|12            |NA                                    |NA               |NA            |N                 |PG WRECKER SERVICE               |4707 W. WALNUT ST 77581                |FAILED TO DRIVE IN SINGLE LANE|NA                |NA                          |EAST           |Y                    |0              |0                 |0             |1            |0             |0            |0        |NO DAMAGES TO THE CITY POLE 214385     |
# |15255328|2       |MOTOR VEHICLE|N            |N         |TX              |1GCFG15X071232961|2007        |WHI         |CHEVROLET  |EXPRESS   |VAN                  |N              |77571   |1                |LIABILITY INSURANCE POLICY  |DISTRIBUTED LEFT SIDE DAMAGE PARALLEL IMPACT |DAMAGED 5        |7             |NA                                    |NA               |NA            |N                 |CITY LIMITS JOSE L CARILLO       |2118 BROOKTREE ST                      |TURNED IMPROPERLY - WRONG LANE|NA                |NA                          |SOUTH          |Y                    |0              |0                 |0             |1            |0             |0            |0        |NONE                                   |
# |14870169|1       |MOTOR VEHICLE|N            |N         |TX              |WA1VMAFE5ED013775|NA          |BLK         |AUDI       |Q7        |SPORT UTILITY VEHICLE|N              |60048   |1                |PROOF OF LIABILITY INSURANCE|DISTRIBUTED LEFT SIDE DAMAGE PARALLEL IMPACT |DAMAGED 5        |9             |NA                                    |NA               |NA            |N                 |DRIVEN AWAY                      |BY DRIVER                              |TURNED WHEN UNSAFE            |NA                |NA                          |WEST           |Y                    |0              |0                 |1             |0            |0             |1            |0        |NONE                                   |
# |14885395|1       |MOTOR VEHICLE|N            |N         |TX              |3GCEC13C17G502983|2007        |MAR         |CHEVROLET  |SILVERADO |PICKUP               |N              |77083   |1                |LIABILITY INSURANCE POLICY  |DISTRIBUTED RIGHT SIDE DAMAGE PARALLEL IMPACT|DAMAGED 6        |NA            |NA                                    |NA               |NA            |Y                 |WEST WAY TOWING                  |940 ST HWY 6 SOUTH                     |DISREGARD STOP AND GO SIGNAL  |NA                |DRIVER INATTENTION          |WEST           |Y                    |0              |0                 |0             |1            |0             |0            |0        |NONE                                   |
# +--------+--------+-------------+-------------+----------+----------------+-----------------+------------+------------+-----------+----------+---------------------+---------------+--------+-----------------+----------------------------+---------------------------------------------+-----------------+--------------+--------------------------------------+-----------------+--------------+------------------+---------------------------------+---------------------------------------+------------------------------+------------------+----------------------------+---------------+---------------------+---------------+------------------+--------------+-------------+--------------+-------------+---------+---------------------------------------+

# %%
df_units_use.select("VEH_DMAG_SCL_2_ID").distinct().show(truncate=False)
# Out:
# +-----------------+
# |VEH_DMAG_SCL_2_ID|
# +-----------------+
# |DAMAGED 4        |
# |INVALID VALUE    |
# |NA               |
# |DAMAGED 5        |
# |DAMAGED 1 MINIMUM|
# |DAMAGED 3        |
# |NO DAMAGE        |
# |DAMAGED 7 HIGHEST|
# |DAMAGED 2        |
# |DAMAGED 6        |
# +-----------------+

# %%
dmg_df = df_units_use.join(df_damages_use, on=['CRASH_ID'], how='inner'). \
filter((F.col("DAMAGED_PROPERTY").rlike("NO DAMAGE")) | (F.col("DAMAGED_PROPERTY").rlike("NONE")))

# %%
dmg_df.select("VEH_DMAG_SCL_2_ID").distinct().show(truncate=False)
# Out:
# +-----------------+
# |VEH_DMAG_SCL_2_ID|
# +-----------------+
# |NA               |
# |DAMAGED 1 MINIMUM|
# |DAMAGED 3        |
# |NO DAMAGE        |
# |DAMAGED 2        |
# +-----------------+

# %%
print("Distinct Crash IDs where No Damaged Property was observed and Damage Level (VEH_DMAG_SCL~) is above 4 and car avails Insurance",insured_no_dmg_property.select("CRASH_ID").distinct().count())
# Out:
# Distinct Crash IDs where No Damaged Property was observed and Damage Level (VEH_DMAG_SCL~) is above 4 and car avails Insurance 10

# %% [markdown]
# ## Analytics 8

# %%
#Determine the Top 5 Vehicle Makes where drivers are charged with speeding related offences,
#has licensed Drivers, uses top 10 used vehicle colours and 
#has car licensed with the Top 25 states with highest number of offences (to be deduced from the data)

# %%
top_25_states = [row[0] for row in df_units_use.filter(F.col("VEH_LIC_STATE_ID").cast("int").isNull()).
            groupby("VEH_LIC_STATE_ID").count().orderBy(F.col("count").desc()).limit(25).collect()]
top_10_used_vcolors = [row[0] for row in df_units_use.filter(df_units_use.VEH_COLOR_ID != "NA").
            groupby("VEH_COLOR_ID").count().orderBy(F.col("count").desc()).limit(10).collect()]

# %%
top_5_veh_makes = df_charges_use.join(df_primary_person_use, on=['CRASH_ID'], how='inner'). \
            join(df_units_use, on=['CRASH_ID'], how='inner'). \
            filter(df_charges_use.CHARGE.contains("SPEED")). \
            filter(df_primary_person_use.DRVR_LIC_TYPE_ID.isin(["DRIVER LICENSE", "COMMERCIAL DRIVER LIC."])). \
            filter(df_units_use.VEH_COLOR_ID.isin(top_10_used_vcolors)). \
            filter(df_units_use.VEH_LIC_STATE_ID.isin(top_25_states)). \
            groupby("VEH_MAKE_ID").count(). \
            orderBy(F.col("count").desc()).limit(5)

# %%
list_veh = ""
for i in  top_5_veh_makes.select('VEH_MAKE_ID').rdd.flatMap(lambda x: x).collect():
  list_veh += i + ", "
list_veh.strip(", ")
# Out:
# 'FORD, CHEVROLET, TOYOTA, DODGE, NISSAN'

# %%
print("Top 5 Vehicle Makes where drivers are charged with speeding related offences, has licensed Drivers, uses top 10 used vehicle colours and has car licensed with the Top 25 states with highest number of offences  are:",list_veh.strip(", "))
# Out:
# Top 5 Vehicle Makes where drivers are charged with speeding related offences, has licensed Drivers, uses top 10 used vehicle colours and has car licensed with the Top 25 states with highest number of offences  are: FORD, CHEVROLET, TOYOTA, DODGE, NISSAN
